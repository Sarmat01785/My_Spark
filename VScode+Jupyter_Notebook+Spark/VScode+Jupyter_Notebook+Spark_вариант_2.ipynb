# %% [markdown]
# ### Настройка `VScode` для работы с `Jupyter Notebook+Spark` вариант 2

# %% [markdown]
# 1. Стартуем `Jupyter Notebook` копируем `token`
#
# 2. Жмём в верхнем правом углу `VScode` Выбор Ядра выбераем существующий сервер `Jupyter...` и вставляем `token`
#
# 3. Далее выбираем `Python 3 (ipykernel)` рекомендуется.

# %%
# Устанавливаем библиотеку findspark   # Если еще не установлена.
# !pip install findspark
# Out:
# Requirement already satisfied: findspark in ./anaconda3/lib/python3.12/site-packages (2.0.1)

# %%
# Импортируем библиотеку findspark для работы с путями Spark
import findspark
findspark.init('/opt/spark')  # Указывает на установку Spark

# %%
# Выводим информацию о версии Spark
# !spark-submit --version
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 25/11/01 20:23:00 WARN Utils: Your hostname, Quantum, resolves to a loopback address: 127.0.0.1; using 192.168.1.133 instead (on interface wlp0s20f3)
# 25/11/01 20:23:00 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Welcome to
#       ____              __
#      / __/__  ___ _____/ /__
#     _\ \/ _ \/ _ `/ __/  '_/
#    /___/ .__/\_,_/_/ /_/\_\   version 4.0.1
#       /_/
#
# Using Scala version 2.13.16, OpenJDK 64-Bit Server VM, 21.0.8
# Branch HEAD
# Compiled by user runner on 2025-09-02T03:10:51Z
# Revision 29434ea766b0fc3c3bf6eaadb43a8f931133649e
# Url https://github.com/apache/spark
# Type --help for more information.

# %%
# Импортируем класс SparkSession из модуля pyspark.sql для создания сеанса Spark.
from pyspark.sql import SparkSession

# %%
# Создаем объект SparkSession с указанием мастера 'local[*]', что означает использование всех ядер процессора,
# и задаем имя приложения "My Spark Application". Метод getOrCreate() возвращает существующий сеанс Spark,
# если он уже был создан, либо создает новый.
spark = SparkSession.builder.master("local[*]").appName("My Spark Application").getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 25/11/01 20:23:09 WARN Utils: Your hostname, Quantum, resolves to a loopback address: 127.0.0.1; using 192.168.1.133 instead (on interface wlp0s20f3)
# 25/11/01 20:23:09 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/11/01 20:23:10 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# Выводим информацию о созданной сессии Spark.
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.1.133:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>My Spark Application</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# Остановка текущего сеанса Spark.
spark.stop()
